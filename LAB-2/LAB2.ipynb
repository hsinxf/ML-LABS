# %%
import pandas as pd

df = pd.read_csv('atp_tennis.csv')
print(f"Shape of dataset: {df.shape} ")
# Out:
# Shape of dataset: (66910, 17)
# /var/folders/ft/hzw_xsnj0vb19nb_sy7bh1xh0000gn/T/ipykernel_84733/688788457.py:3: DtypeWarning: Columns (0: Odd_2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('atp_tennis.csv')

# %%
print(f"First 5 rows:\n{df.head()}")
# Out:
# First 5 rows:
#                            Tournament        Date         Series    Court  \
# 0  Australian Hardcourt Championships  2000-01-03  International  Outdoor
# 1  Australian Hardcourt Championships  2000-01-03  International  Outdoor
# 2  Australian Hardcourt Championships  2000-01-03  International  Outdoor
# 3  Australian Hardcourt Championships  2000-01-03  International  Outdoor
# 4  Australian Hardcourt Championships  2000-01-03  International  Outdoor
#
#   Surface      Round  Best of        Player_1       Player_2       Winner  \
# 0    Hard  1st Round        3      Dosedel S.    Ljubicic I.   Dosedel S.
# 1    Hard  1st Round        3      Clement A.     Enqvist T.   Enqvist T.
# 2    Hard  1st Round        3       Escude N.  Baccanello P.    Escude N.
# 3    Hard  1st Round        3  Knippschild J.     Federer R.   Federer R.
# 4    Hard  1st Round        3     Fromberg R.  Woodbridge T.  Fromberg R.
#
#    Rank_1  Rank_2  Pts_1  Pts_2  Odd_1 Odd_2        Score
# ...

# %%
print(f"Last 5 rows:\n{df.tail()}")
# Out:
# Last 5 rows:
#             Tournament        Date      Series    Court Surface  \
# 66905  Australian Open  2026-01-27  Grand Slam  Outdoor    Hard
# 66906  Australian Open  2026-01-28  Grand Slam  Outdoor    Hard
# 66907  Australian Open  2026-01-30  Grand Slam  Outdoor    Hard
# 66908  Australian Open  2026-01-30  Grand Slam  Outdoor    Hard
# 66909  Australian Open  2026-02-01  Grand Slam  Outdoor    Hard
#
#                Round  Best of      Player_1    Player_2       Winner  Rank_1  \
# 66905  Quarterfinals        5  De Minaur A.  Alcaraz C.   Alcaraz C.       6
# 66906  Quarterfinals        5     Sinner J.  Shelton B.    Sinner J.       2
# 66907     Semifinals        5     Zverev A.  Alcaraz C.   Alcaraz C.       3
# 66908     Semifinals        5   Djokovic N.   Sinner J.  Djokovic N.       4
# 66909      The Final        5   Djokovic N.  Alcaraz C.   Alcaraz C.       4
#
#        Rank_2  Pts_1  Pts_2  Odd_1 Odd_2                Score
# ...

# %%
print("Dataset Info: ")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 66910 entries, 0 to 66909
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tournament  66910 non-null  str
#  1   Date        66910 non-null  str
#  2   Series      66910 non-null  str
#  3   Court       66910 non-null  str
#  4   Surface     66910 non-null  str
#  5   Round       66910 non-null  str
#  6   Best of     66910 non-null  int64
#  7   Player_1    66910 non-null  str
#  8   Player_2    66910 non-null  str
#  9   Winner      66910 non-null  str
#  10  Rank_1      66910 non-null  int64
#  11  Rank_2      66910 non-null  int64
#  12  Pts_1       66910 non-null  int64
#  13  Pts_2       66910 non-null  int64
#  14  Odd_1       66910 non-null  float64
#  15  Odd_2       66910 non-null  object
#  16  Score       66910 non-null  str
# dtypes: float64(1), int64(5), object(1), str(10)
# memory usage: 8.7+ MB
# None
